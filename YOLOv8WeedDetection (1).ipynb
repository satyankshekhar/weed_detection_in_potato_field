# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="OX6NFCBzCriQTqqgNZXZ")
project = rf.workspace("project-mqcj4").project("my-first-project-ozzzj")
version = project.version(14)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 96.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 143.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-14 in yolov8:: 100%|██████████| 2786/2786 [00:03<00:00, 803.88it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # ✅ detection model

results = model.train(
    data="/content/My-First-Project-14/data.yaml",
    epochs=50,
    imgsz=640,
    batch=2,
    device="cpu"
)
# Out:
# Ultralytics 8.4.32 🚀 Python-3.12.13 torch-2.10.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# ...

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
# Out:
# True
# 1

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")  # detection model (better than nano)

results = model.train(
    data="/content/My-First-Project-14/data.yaml",
    epochs=50,
    imgsz=640,
    batch=8,
    device=0   # GPU
)
# Out:
# ...
# Ultralytics 8.4.32 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.4.32 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4564.7±941.3 MB/s, size: 866.8 KB)
# val: Scanning /content/My-First-Project-14/valid/labels.cache... 183 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 183/183 69.8Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 482, len(boxes) = 483. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.1it/s 5.8s
#                    all        183        483      0.646      0.662      0.651      0.524
#                   Weed        115        320      0.457      0.416      0.373      0.243
# ...

# %%
from google.colab import files
files.download("runs")

# %%
# !zip -r runs.zip runs/
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/train3/ (stored 0%)
#   adding: runs/detect/train3/train_batch2.jpg (deflated 23%)
#   adding: runs/detect/train3/args.yaml (deflated 52%)
#   adding: runs/detect/train3/train_batch1.jpg (deflated 13%)
#   adding: runs/detect/train3/train_batch0.jpg (deflated 12%)
#   adding: runs/detect/train3/weights/ (stored 0%)
#   adding: runs/detect/train3/labels.jpg (deflated 26%)
#   adding: runs/detect/train4/ (stored 0%)
#   adding: runs/detect/train4/train_batch2.jpg (deflated 4%)
#   adding: runs/detect/train4/val_batch1_labels.jpg (deflated 4%)
#   adding: runs/detect/train4/confusion_matrix.png (deflated 33%)
#   adding: runs/detect/train4/val_batch0_labels.jpg (deflated 5%)
#   adding: runs/detect/train4/results.png (deflated 6%)
#   adding: runs/detect/train4/train_batch5082.jpg (deflated 9%)
#   adding: runs/detect/train4/val_batch2_pred.jpg (deflated 4%)
# ...
